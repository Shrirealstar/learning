# %%
import requests
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
api_key = os.environ['GOOGLE_API_KEY']

# Set the API endpoint and API key.
endpoint = "https://generativelanguage.googleapis.com/v1beta"
# Prepare the request body.
request_body = {
    "contents": [
        {
            "parts": [
                {
                    "text": "Write a story about a Bijapur"
                }
            ]
        }
    ]
}

# Make the request.
response = requests.post(
    f"{endpoint}/models/gemini-pro:generateContent?key={api_key}",
    json=request_body,
)

# Parse the response.
response_json = response.json()

generated_content = response_json["candidates"][0]['content']['parts'][0]['text']

# Print the generated content.
print(generated_content)
# Out:
# Amidst the sun-drenched Deccan Plateau, where the history of empires unfolded, lay the ancient city of Bijapur. Once the proud capital of the Adil Shahi Dynasty, Bijapur's legacy lived on through its majestic monuments and enigmatic tales.
#
# One such tale was that of the enigmatic queen, Chand Bibi. A formidable ruler, she had ascended to the throne in a time of turmoil. With wisdom and diplomacy, she navigated the treacherous waters of court intrigue, repelling foreign invaders and ensuring the stability of her kingdom.
#
# In the heart of Bijapur stood the Gol Gumbaz, the resting place of Chand Bibi and her father. Its colossal dome, the largest in India, echoed with the grandeur of a bygone era. Its intricate mosaic tiles and arched balconies spoke of the architectural brilliance of its time.
#
# As the sun began its descent, casting an ethereal glow over the city, a group of travelers ventured into the Gol Gumbaz. They were led by Dr. Amir, a renowned historian, who had dedicated his life to unraveling the mysteries of Bijapur.
#
# "This magnificent structure," Dr. Amir explained, "is a testament to the architectural prowess of the Adil Shahi kingdom. Its innovative design and acoustic wonders have been the subject of study for centuries."
#
# The travelers marveled at the massive pillars and Whispering Gallery, where even the softest whisper could be heard from across the dome. They were transported back in time, imagining the courtly life that had once flourished within these walls.
#
# As darkness enveloped Bijapur, the travelers made their way to the Bara Kaman, a towering gateway that once marked the entrance to Chand Bibi's palace. Here, they listened to the haunting legend of the headless ghost of a murdered courtier, who roamed the hallways at night seeking revenge.
#
# "The tales that surround this city," Dr. Amir said, "are as captivating as its history. They remind us of the triumphs and tragedies, the grandeur and intrigue that permeated these ancient lands."
#
# With the last rays of sunlight fading away, the travelers emerged from Bijapur, their minds filled with the echoes of history. The city's timeless monuments and enigmatic stories would forever hold a special place in their hearts, reminding them of the grandeur and legacy of the Deccan's past.

# %%
testing_guidelines = """

Certainly! Testing a chatbot involves various aspects to ensure it meets the desired functionality, performance, and user experience. Below are some guidelines for testing a chatbot:

1. Functional Testing:
User Input Handling:

Test the chatbot's ability to understand and process different types of user inputs.
Check for handling of various formats, languages, and potential user errors.
Intent Recognition:

Verify that the chatbot accurately recognizes user intents and responds accordingly.
Test the coverage of different predefined intents.
Entity Recognition:

Ensure that the chatbot correctly identifies and extracts entities from user input.
Check for variations in entity formats.
Conversation Flow:

Test the flow of a conversation to ensure a smooth transition between user queries.
Verify that the chatbot maintains context and remembers previous interactions.
2. User Experience (UX) Testing:
Natural Language Understanding:

Evaluate the chatbot's ability to understand and respond in a natural and user-friendly manner.
Check for responses that are clear, concise, and contextually relevant.
User Guidance:

Ensure the chatbot provides clear instructions and guidance to users.
Test the handling of ambiguous or unclear queries.
Error Handling:

Verify that the chatbot gracefully handles errors and provides helpful error messages.
Test for edge cases and unexpected user inputs.
3. Performance Testing:
Response Time:

Measure the time it takes for the chatbot to respond to user queries.
Ensure responses are delivered within an acceptable timeframe.
Concurrency Testing:

Test the chatbot's performance under simultaneous user interactions.
Check if the chatbot maintains responsiveness during peak usage.
4. Security Testing:
Data Privacy:

Ensure that the chatbot handles user data securely and follows data privacy regulations.
Test for potential security vulnerabilities.
Authentication and Authorization:

Verify that the chatbot properly authenticates users and restricts access as needed.
5. Integration Testing:
External Integrations:

Test any external integrations, such as database connections, API calls, or third-party services.
Ensure data consistency and accuracy.
Platform Compatibility:

Test the chatbot on different platforms and devices to ensure compatibility.
Verify that it works well on various web browsers and mobile devices.
6. Regression Testing:
Continuous Testing:
Perform regression testing after any updates or changes to the chatbot.
Ensure that existing functionalities remain unaffected.
7. User Acceptance Testing (UAT):
End-User Involvement:
Involve end-users in the testing process to gather feedback on usability and functionality.
Address any user-reported issues or concerns.
8. Documentation:
Test Documentation:
Maintain comprehensive test documentation, including test cases, test results, and any discovered issues.
Document steps to reproduce bugs and suggested resolutions.
9. Scalability Testing:
Scalability Assessment:
Test the chatbot's performance as the user base grows.
Ensure scalability by simulating an increasing number of users.
10. Continuous Monitoring:
Monitoring and Analytics:
Implement monitoring tools to track the chatbot's performance and user interactions.
Analyze user feedback and adjust the chatbot accordingly.
11. Accessibility Testing:
Accessibility Compliance:
Ensure the chatbot is accessible to users with disabilities.
Test with screen readers and other assistive technologies.
12. Multilingual Testing:
Language Support:
If the chatbot supports multiple languages, verify that it performs well in each supported language.
Test for language-specific nuances and variations.
13. Compliance Testing:
Regulatory Compliance:
Ensure the chatbot complies with relevant industry regulations and standards.
Address any legal and compliance requirements.
14. Usability Testing:
User Feedback:
Collect feedback from real users to evaluate the overall usability and satisfaction.
Make improvements based on user suggestions.
15. Cross-Browser and Cross-Device Testing:
Browser Compatibility:
Test the chatbot on different web browsers to ensure compatibility.
Device Compatibility:
Verify that the chatbot works well on various devices, including desktops, tablets, and mobile phones.
16. Exploratory Testing:
Exploratory Sessions:
Conduct exploratory testing to uncover any unforeseen issues.
Encourage testers to interact with the chatbot in creative ways.
17. Load Testing:
Load Handling:
Simulate high loads and assess how the chatbot handles increased traffic.
Identify any performance bottlenecks.
18. Adaptability Testing:
Adaptability to Context:
Test the chatbot's ability to adapt to context changes during a conversation.
Ensure it handles interruptions and context shifts gracefully.
19. Cultural Sensitivity Testing:
Cultural Adaptation:
Verify that the chatbot's responses are culturally sensitive and appropriate.
Consider regional variations and cultural norms.
20. User Persona Testing:
User Personas:
Test the chatbot with different user personas to ensure it caters to diverse user groups.
Assess how well the chatbot understands and responds to different user characteristics.
These guidelines cover various aspects of testing a chatbot, and the specific tests you perform may depend on the features and functionalities of your chatbot. Continuous testing and user feedback are crucial for maintaining and improving the quality of your chatbot over time.
"""

# %%
chat_history = """

"""

# %%
chat_conversation = """
User: Hello!
Chatbot: Hi there! How can I assist you today?

User: I'm feeling a bit lost in my career path. Any advice?
Chatbot: Finding the right career path can be challenging. Have you identified your interests and strengths?

User: Yes, I think I'm good at writing and communication.
Chatbot: That's great to hear! Have you considered exploring fields like journalism, marketing, or content writing?

User: I've thought about it, but I'm not sure where to start.
Chatbot: You could start by researching different industries and job roles related to writing and communication. Networking with professionals in those fields can also provide valuable insights.

User: That sounds like a good idea. Thanks for the advice!
Chatbot: You're welcome! Remember, it's important to explore your options and stay open to new opportunities. If you have any more questions, feel free to ask!

User: Will do. Thanks again!
Chatbot: No problem at all. Wishing you the best of luck on your career journey!"""

# %%
prompt = f" This is a chat conversation between a user and a chatbot. Design test scenarios and list comprehensive test cases for such a converstaion to identify errors and evaluate response. Please use the relevant chatbot testing guidelines. The conversation is given here {chat_conversation}"

# %%
import requests
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file
api_key = os.environ['GOOGLE_API_KEY']

# Set the API endpoint and API key.
endpoint = "https://generativelanguage.googleapis.com/v1beta"
# Prepare the request body.
request_body = {
    "contents": [
        {
            "parts": [
                {
                    "text": prompt
                }
            ]
        }
    ]
}

# Make the request.
response = requests.post(
    f"{endpoint}/models/gemini-pro:generateContent?key={api_key}",
    json=request_body,
)

# Parse the response.
response_json = response.json()

generated_content = response_json["candidates"][0]['content']['parts'][0]['text']

# Print the generated content.
print(generated_content)
# Out:
# **Test Scenarios**
#
# **1. Accuracy and Reliability**
# * Verify that the chatbot responds with accurate and reliable information.
# * Test if the chatbot can handle inquiries on various topics and provides comprehensive answers.
#
# **2. User Intent Recognition**
# * Evaluate the chatbot's ability to understand and fulfill a user's intent.
# * Test if the chatbot can respond appropriately to different types of questions and requests.
#
# **3. Conversational Flow**
# * Check if the chatbot maintains a smooth and natural conversational flow.
# * Test if the chatbot responds in a timely manner and avoids irrelevant or repetitive information.
#
# **4. Error Handling and Recovery**
# * Simulate scenarios where the chatbot encounters errors or misunderstandings.
# * Test if the chatbot can handle errors gracefully and provide helpful guidance or recovery options.
#
# **5. Personalization and Context Awareness**
# * Check if the chatbot can personalize responses based on a user's previous interactions or preferences.
# * Test if the chatbot retains context and adjusts its responses accordingly.
#
# **Comprehensive Test Cases**
#
# **1. Accuracy and Reliability**
# * **Test Case:** Ask detailed questions on specific topics, such as historical events or scientific concepts.
# * **Expected Result:** The chatbot should provide accurate and verifiable information.
#
# **2. User Intent Recognition**
# * **Test Case:** Input questions with varying levels of ambiguity or impreciseness.
# * **Expected Result:** The chatbot should correctly identify the user's intent and respond appropriately.
#
# **3. Conversational Flow**
# * **Test Case:** Engage in extended conversations, asking follow-up questions or changing topics.
# * **Expected Result:** The chatbot should maintain a cohesive and engaging dialogue without abrupt interruptions or irrelevant responses.
#
# **4. Error Handling and Recovery**
# * **Test Case:** Use misspelled words or grammatically incorrect sentences.
# * **Expected Result:** The chatbot should recognize the error, provide a helpful message, and offer suggestions for correction.
#
# **5. Personalization and Context Awareness**
# * **Test Case:** Use a chatbot that allows for user profiles or preferences.
# * **Expected Result:** The chatbot should personalize responses based on the user's profile or previous interactions.
